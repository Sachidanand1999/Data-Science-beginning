# %% [markdown]
# # EDA and Graphical Representation

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
cars = pd.read_csv(r"E:\Python Task\Cars.csv")

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.tail()
# Out:
#      HP        MPG  VOL          SP         WT
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %% [markdown]
# # EDA

# %% [markdown]
# - First moment

# %% [markdown]
# 1. Mean

# %%
cars.mean()
# Out:
# HP     117.469136
# MPG     34.422076
# VOL     98.765432
# SP     121.540272
# WT      32.412577
# dtype: float64

# %% [markdown]
# 2. Median

# %%
cars.median()
# Out:
# HP     100.000000
# MPG     35.152727
# VOL    101.000000
# SP     118.208698
# WT      32.734518
# dtype: float64

# %% [markdown]
# 3. Mode

# %%
cars.mode()
# Out:
#       HP        MPG   VOL          SP         WT
# 0   92.0  29.629936  50.0  118.288996  15.712859
# 1    NaN        NaN   NaN         NaN  15.753535
# 2    NaN        NaN   NaN         NaN  15.769625
# 3    NaN        NaN   NaN         NaN  15.823060
# 4    NaN        NaN   NaN         NaN  15.847758
# ..   ...        ...   ...         ...        ...
# 76   NaN        NaN   NaN         NaN  42.778219
# 77   NaN        NaN   NaN         NaN  43.353123
# 78   NaN        NaN   NaN         NaN  43.390988
# 79   NaN        NaN   NaN         NaN  44.013139
# 80   NaN        NaN   NaN         NaN  52.997752
#
# [81 rows x 5 columns]

# %% [markdown]
# - Second moment

# %% [markdown]
# 1. Variance

# %%
cars.var()
# Out:
# HP     3261.952160
# MPG      83.383283
# VOL     497.356790
# SP      201.113002
# WT       56.142247
# dtype: float64

# %% [markdown]
# 2. Standard Deviation

# %%
cars.std()
# Out:
# HP     57.113502
# MPG     9.131445
# VOL    22.301497
# SP     14.181432
# WT      7.492813
# dtype: float64

# %% [markdown]
# - Third moment

# %% [markdown]
# 1. Skewness

# %%
cars.skew()
# Out:
# HP     1.716216
# MPG   -0.177947
# VOL   -0.590197
# SP     1.611450
# WT    -0.614753
# dtype: float64

# %% [markdown]
# - Fourth moment

# %% [markdown]
# 1. Kurtosis

# %%
cars.kurt()
# Out:
# HP     2.960025
# MPG   -0.611679
# VOL    0.920229
# SP     2.977329
# WT     0.950291
# dtype: float64

# %% [markdown]
# # Graphical Representation

# %% [markdown]
# 1. Univariate Analysis

# %% [markdown]
# a. Barplot

# %%
plt.bar( height = cars['HP'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['MPG'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['VOL'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['SP'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['WT'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %% [markdown]
# b. Histogram

# %%
plt.hist(cars)
# Out:
# (array([[ 0., 15., 35.,  9., 13.,  2.,  0.,  3.,  2.,  2.],
#         [67., 14.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [ 0.,  9., 42., 29.,  1.,  0.,  0.,  0.,  0.,  0.],
#         [ 0.,  0.,  5., 68.,  6.,  2.,  0.,  0.,  0.,  0.],
#         [77.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 12.10126289,  43.0911366 ,  74.08101031, 105.07088402,
#         136.06075773, 167.05063144, 198.04050516, 229.03037887,
#         260.02025258, 291.01012629, 322.        ]),
#  <a list of 5 BarContainer objects>)

# %%
plt.hist( cars['HP'], color = 'orange', edgecolor = 'black', bins = 7)
# Out:
# (array([22., 34., 16.,  2.,  2.,  3.,  2.]),
#  array([ 49.,  88., 127., 166., 205., 244., 283., 322.]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist( cars['MPG'], color = 'orange', edgecolor = 'black', bins = 7)
# Out:
# (array([ 1., 15., 11., 16., 20., 13.,  5.]),
#  array([12.10126289, 18.04403696, 23.98681103, 29.9295851 , 35.87235917,
#         41.81513324, 47.75790731, 53.70068138]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist( cars['VOL'], color = 'orange', edgecolor = 'black', bins = 7)
# Out:
# (array([ 9.,  0., 26., 23., 17.,  5.,  1.]),
#  array([ 50.        ,  65.71428571,  81.42857143,  97.14285714,
#         112.85714286, 128.57142857, 144.28571429, 160.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist( cars['SP'], color = 'orange', edgecolor = 'black', bins = 7)
# Out:
# (array([ 9., 40., 16.,  8.,  2.,  3.,  3.]),
#  array([ 99.56490661, 109.56970749, 119.57450838, 129.57930926,
#         139.58411015, 149.58891103, 159.59371192, 169.5985128 ]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist( cars['WT'], color = 'orange', edgecolor = 'black', bins = 7)
# Out:
# (array([ 9.,  0., 25., 23., 18.,  5.,  1.]),
#  array([15.71285853, 21.03927193, 26.36568534, 31.69209874, 37.01851215,
#         42.34492555, 47.67133896, 52.99775236]),
#  <BarContainer object of 7 artists>)

# %% [markdown]
# c. Boxplot

# %%
sns.boxplot(cars)
# Out:
# <Axes: >

# %%
plt.boxplot(cars)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ed0e710cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ed0e712050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ed0e710550>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1ed0e712790>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1ed0e713990>,
# ...
#  'means': []}

# %%
cars.plot( kind = 'box', subplots = True, sharey = False, figsize = (10,5))
plt.subplots_adjust(wspace = 0.50)

# %% [markdown]
# - Bivariate Analysis

# %% [markdown]
# a. Scatterplot

# %%
plt.scatter( x = cars['HP'], y = cars['MPG'] )

# %%
plt.scatter( x = cars['HP'], y = cars['VOL'] )

# %%
plt.scatter( x = cars['HP'], y = cars['SP'] )

# %%
plt.scatter( x = cars['HP'], y = cars['WT'] )
