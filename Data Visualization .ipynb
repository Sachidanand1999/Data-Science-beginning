# %% [markdown]
# # Importing packages

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the datset

# %%
cars = pd.read_csv(r"E:\Python Task\Cars.csv")

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.tail()
# Out:
#      HP        MPG  VOL          SP         WT
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %% [markdown]
# ### First moment

# %%
cars.mean()
# Out:
# HP     117.469136
# MPG     34.422076
# VOL     98.765432
# SP     121.540272
# WT      32.412577
# dtype: float64

# %%
cars.median()
# Out:
# HP     100.000000
# MPG     35.152727
# VOL    101.000000
# SP     118.208698
# WT      32.734518
# dtype: float64

# %%
cars.mode()
# Out:
#       HP        MPG   VOL          SP         WT
# 0   92.0  29.629936  50.0  118.288996  15.712859
# 1    NaN        NaN   NaN         NaN  15.753535
# 2    NaN        NaN   NaN         NaN  15.769625
# 3    NaN        NaN   NaN         NaN  15.823060
# 4    NaN        NaN   NaN         NaN  15.847758
# ..   ...        ...   ...         ...        ...
# 76   NaN        NaN   NaN         NaN  42.778219
# 77   NaN        NaN   NaN         NaN  43.353123
# 78   NaN        NaN   NaN         NaN  43.390988
# 79   NaN        NaN   NaN         NaN  44.013139
# 80   NaN        NaN   NaN         NaN  52.997752
#
# [81 rows x 5 columns]

# %% [markdown]
# ### Second moment

# %%
cars.var()
# Out:
# HP     3261.952160
# MPG      83.383283
# VOL     497.356790
# SP      201.113002
# WT       56.142247
# dtype: float64

# %%
cars.std()
# Out:
# HP     57.113502
# MPG     9.131445
# VOL    22.301497
# SP     14.181432
# WT      7.492813
# dtype: float64

# %% [markdown]
# ### Third moment

# %%
cars.skew()
# Out:
# HP     1.716216
# MPG   -0.177947
# VOL   -0.590197
# SP     1.611450
# WT    -0.614753
# dtype: float64

# %% [markdown]
# ### Fourth moment

# %%
cars.kurt()
# Out:
# HP     2.960025
# MPG   -0.611679
# VOL    0.920229
# SP     2.977329
# WT     0.950291
# dtype: float64

# %% [markdown]
# ### Barplot or Bargraph

# %%
plt.bar( height = cars['HP'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['MPG'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['VOL'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['SP'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar( height = cars['WT'], x = np.arange(1,82,1))
# Out:
# <BarContainer object of 81 artists>

# %% [markdown]
# ### Histogram

# %%
plt.hist(cars)
# Out:
# (array([[ 0., 15., 35.,  9., 13.,  2.,  0.,  3.,  2.,  2.],
#         [67., 14.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [ 0.,  9., 42., 29.,  1.,  0.,  0.,  0.,  0.,  0.],
#         [ 0.,  0.,  5., 68.,  6.,  2.,  0.,  0.,  0.,  0.],
#         [77.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 12.10126289,  43.0911366 ,  74.08101031, 105.07088402,
#         136.06075773, 167.05063144, 198.04050516, 229.03037887,
#         260.02025258, 291.01012629, 322.        ]),
#  <a list of 5 BarContainer objects>)

# %%
for i in cars.columns:
    plt.hist( x = cars[i] )
    plt.title( 'Histogram of ' + str(i))
    plt.show()

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(cars)
# Out:
# <Axes: >

# %%
plt.boxplot(cars)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23094f17850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23094f29090>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23094ee2c50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x23094f2a450>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x23094f2ae90>,
# ...
#  'means': []}

# %%
cars.plot( kind = 'box', subplots = True, sharey = False, figsize = (10,5))
plt.title( 'Outlier Analysis with Boxplot')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
plt.scatter( x = cars['HP'], y = cars['MPG'] )

# %%
plt.scatter( x = cars['HP'], y = cars['VOL'] )

# %%
plt.scatter( x = cars['HP'], y = cars['WT'] )

# %%
plt.scatter( x = cars['HP'], y = cars['SP'] )

# %%
sns.pairplot(cars)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### Heatmap

# %%
corr_mat = cars.corr( method = 'pearson' )

# %%
print(corr_mat)
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap( corr_mat, xticklabels = corr_mat.columns, yticklabels = corr_mat.columns, cmap = 'coolwarm' )
plt.tight_layout()
plt.title( 'Heatmap of cars dataset' )
plt.show()

# %% [markdown]
# ### Probability plot

# %%
import scipy.stats as stats

# %%
import pylab

# %%
stats.probplot( cars['HP'], dist = "norm", plot = pylab )
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %%
stats.probplot( cars['MPG'], dist = "norm", plot = pylab )
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %%
stats.probplot( cars['VOL'], dist = "norm", plot = pylab )
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %%
stats.probplot( cars['WT'], dist = "norm", plot = pylab )
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...

# %%
stats.probplot( cars['SP'], dist = "norm", plot = pylab )
# Out:
# ((array([-2.38580629, -2.03993451, -1.8388487 , -1.69267138, -1.57568407,
#          -1.47698662, -1.3908866 , -1.31401722, -1.24421348, -1.17999652,
#          -1.1203088 , -1.06436632, -1.01157066, -0.96145394, -0.91364281,
#          -0.8678341 , -0.82377792, -0.78126552, -0.7401204 , -0.7001918 ,
#          -0.66134962, -0.62348064, -0.58648548, -0.55027625, -0.51477465,
#          -0.47991041, -0.4456201 , -0.41184603, -0.37853543, -0.34563975,
#          -0.31311399, -0.28091622, -0.24900715, -0.21734968, -0.1859086 ,
#          -0.15465028, -0.12354237, -0.09255359, -0.06165345, -0.03081208,
#           0.        ,  0.03081208,  0.06165345,  0.09255359,  0.12354237,
#           0.15465028,  0.1859086 ,  0.21734968,  0.24900715,  0.28091622,
#           0.31311399,  0.34563975,  0.37853543,  0.41184603,  0.4456201 ,
#           0.47991041,  0.51477465,  0.55027625,  0.58648548,  0.62348064,
#           0.66134962,  0.7001918 ,  0.7401204 ,  0.78126552,  0.82377792,
# ...
